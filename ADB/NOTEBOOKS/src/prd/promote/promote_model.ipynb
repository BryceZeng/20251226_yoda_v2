# %%
env = dbutils.widgets.get("ENV")

# %%
if env == "dev":
  dbutils.notebook.exit(0)

# %%
src_model_name = dbutils.widgets.get("MODEL_NAME")
dst_model_name = dbutils.widgest.get("DEST_MODEL_NAME")

# %%
import os

from databricks.feature_engineering import FeatureLookup
from databricks.feature_engineering import FeatureEngineeringClient

import helper as pp

import mlflow
from mlflow.tracking.client import MlflowClient

# %%
client = MlflowClient(registry_uri="databricks-uc")
mlflow.set_registry_uri('databricks-uc')

# %%
src_model_uri = f"models:/{src_model_name}@champion"
dst_model_name = "pru_prod.pac_mlops.fraud_detection"
copied_model_version = client.copy_model_version(src_model_uri, dst_model_name)

# %%
dest_model_version = copied_model_version.version

# %%
client.set_registered_model_alias(
      name=dst_model_name,
      alias="Champion",
      version=dest_model_version
    )
print(f"Model {dst_model_name} version {dest_model_version} registered as Champion")
